# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mtl

# %%
from IPython.display import HTML, display

html = """
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<title>Índice de Felicidad — Colombia</title>
<style>

body {
    font-family: Arial, sans-serif;
    background-color: #f4f6f8;
    margin: 0;
}

header {
    background-color: #1f3c88;
    color: white;
    padding: 30px;
    text-align: center;
}

section {
    background: white;
    margin: 25px auto;
    padding: 25px;
    width: 90%;
    max-width: 1000px;
    border-radius: 12px;
    box-shadow: 0 3px 10px rgba(0,0,0,0.1);
}

h2 {
    color: #1f3c88;
}

p {
    line-height: 1.6;
    color: #333;
}

img {
    width: 100%;
    border-radius: 8px;
    margin-top: 15px;
}

footer {
    text-align: center;
    padding: 20px;
    color: #777;
}

</style>
</head>

<body>

<header>
<h1>Índice de Felicidad Mundial</h1>
<p>Comparación de Colombia con otros países</p>
</header>

<section>
<h2>Introducción</h2>
<p>
El Índice de Felicidad Mundial mide el bienestar de la población a partir de factores como
el ingreso económico, el apoyo social, la salud, la libertad para tomar decisiones y la percepción
de corrupción. Este análisis permite comprender no solo qué países son más felices, sino también
qué elementos contribuyen a esa felicidad.
</p>

<p>
En esta página se presenta una comparación del nivel de felicidad de Colombia frente a otros países
del mundo, incluyendo naciones con altos índices de bienestar, países de la misma región y aquellos
con niveles similares. Además, se analiza la evolución de la felicidad en Colombia a lo largo del tiempo.
</p>
</section>

<section>
<h2>Evolución de la felicidad en Colombia</h2>
<p>
Esta gráfica muestra cómo ha cambiado la evaluación de vida promedio en Colombia a lo largo de los años.
Se observa un aumento en los primeros años, seguido de una disminución progresiva y una leve recuperación
reciente. Esto refleja cómo factores económicos, sociales y políticos pueden influir en el bienestar de
la población a lo largo del tiempo.
</p>
<img src="trend_of_Colombias_life_evaluation_over_the_years.png">
</section>

<section>
<h2>Colombia comparada con los países más felices</h2>
<p>
Aquí se compara a Colombia con algunos de los países con mayor nivel de felicidad del mundo.
Se observa que estas naciones presentan mayores valores en factores como ingreso per cápita,
apoyo social y esperanza de vida saludable, lo que explica su mejor posición en el ranking global.
</p>
<img src="comparacion los mejores.png">
</section>

<section>
<h2>Comparación con países de bajo índice de felicidad</h2>
<p>
En esta gráfica se analizan países con niveles bajos de felicidad. Colombia se encuentra en una
posición intermedia, con mejores resultados en apoyo social y estabilidad que estas naciones,
pero aún lejos de los países más desarrollados.
</p>
<img src="comparacion los mejores2.png">
</section>

<section>
<h2>Países con niveles similares a Colombia</h2>
<p>
Esta comparación permite observar países que tienen puntuaciones cercanas a la de Colombia.
Se aprecia que comparten características similares en factores económicos y sociales,
lo que sugiere que enfrentan desafíos parecidos en términos de bienestar.
</p>
<img src="comparación_con_los_de_su_rango.png">
</section>

<section>
<h2>Comparación con países de Latinoamérica</h2>
<p>
Aquí se analiza la posición de Colombia dentro de su propia región. Aunque algunos países
latinoamericanos presentan mejores resultados en ciertos factores, Colombia mantiene un nivel
de felicidad comparable al promedio regional, destacándose especialmente en apoyo social.
</p>
<img src="comparacion_con_latinoamérica.png">
</section>

<section>
<h2>Factores que influyen en la felicidad (2024)</h2>
<p>
Esta gráfica desglosa los principales componentes que explican la evaluación de vida en 2024.
Entre ellos destacan el ingreso económico, el apoyo social y la libertad para tomar decisiones.
El componente denominado "dystopia + residual" representa factores no medidos directamente,
como estabilidad política, seguridad y calidad institucional.
</p>
<img src="contributing_factors_2024.png">
</section>

<footer>
<p>Fuente: World Happiness Report</p>
</footer>

</body>
</html>
"""

display(HTML(html))
